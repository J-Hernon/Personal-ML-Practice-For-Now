# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Note to self: want to create brief guide for pretty much all basics up to functions. Include operators, defining variables, loops, conditionals. Do seperate files for lists and disctionaries to cover thier specific stuff.
